# %%
import pandas as pd
import numpy as np
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import re
def str2int(text):
  num = re.sub('[\{\}\[\]\/?.,;:|\)*~`!^\-_+<>@\#$%\\\=\(\'\"]','',text)
  return num

# %%
master = pd.read_csv('gdrive/My Drive/공모전/엘포인트/Master.csv')
master.head()
# Out:
#     PD_C                                              PD_NM   CLAC1_NM  \
# 0  64382   언더아머 남성 UA HG 아머 모크 LS 1289559-001 - 블랙 / MD[95]      스포츠패션
# 1  62282                         여자 플라워덧신 2족선물세트 17403-2set  속옷/양말/홈웨어
# 2  61729                       88A2933253배트맨스웨트티 - 블랙 / 130      유아동의류
# 3  61537            닥터마틴 아드리안 블랙, 체리레드 - 02_체리레드 / 250mm(6)       패션잡화
# 4  58820  여성 그레이 스트라이프 퍼프 소매 블라우스 (128865YQ33) - 회색(앤틱실버...       남성의류
#
#     CLAC2_NM  CLAC3_NM
# 0  남성일반스포츠의류  남성스포츠티셔츠
# 1      여성양말류    여성일반양말
# 2     유아의류상의  영유아티셔츠/탑
# 3        남성화      남성부츠
# 4     남성의류상의    남성남방셔츠

# %%
sch1 = pd.read_csv('gdrive/My Drive/공모전/엘포인트/Search1.csv')
sch1.head()
# Out:
#    CLNT_ID  SESS_ID     KWD_NM  SEARCH_CNT
# 0  5607714  7112876   빌리프 아이크림           6
# 1  5607714  4090791  프리메라 마스크팩           3
# 2  5607714  4090791      여성청결제           1
# 3  5612428  1876482       명품가방           1
# 4  5612428   658123  콩순이 아이스크림           1

# %%
pd.pivot_table(sch1, values = 'SEARCH_CNT', columns = 'KWD_NM', aggfunc = np.sum)
# Out:
# KWD_NM       .   0  018501  027250  027545  028205  028250  028503  028510  \
# SEARCH_CNT  16  22      73      24       9       5      34      19      18
#
# KWD_NM      028520  ...   힙색 나이키  힙색 노스페이스  힙색크로스백  힙섹  힙시트   힙쌕  힙업  힙업거들  \
# SEARCH_CNT      25  ...       24        48      54  13   68  250  22    33
#
# KWD_NM      힙업밴드  힙업팬티
# SEARCH_CNT    13    41
#
# [1 rows x 81539 columns]

# %%
sch2 = pd.read_csv('gdrive/My Drive/공모전/엘포인트/Search2.csv')
sch2.head()
# Out:
#     SESS_DT     KWD_NM SEARCH_CNT
# 0  20180407      닥스원피스          8
# 1  20180407  닥터지 브라이트닝          1
# 2  20180407     달팡 인트랄          2
# 3  20180407        대상트          1
# 4  20180407       더블유닷          6

# %%
sch2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8051172 entries, 0 to 8051171
# Data columns (total 3 columns):
# SESS_DT       int64
# KWD_NM        object
# SEARCH_CNT    object
# dtypes: int64(1), object(2)
# memory usage: 184.3+ MB

# %%
sess = pd.read_csv('gdrive/My Drive/공모전/엘포인트/Session.csv')
sess.head()
# Out:
#    CLNT_ID   SESS_ID  SESS_SEQ   SESS_DT  TOT_PAG_VIEW_CT TOT_SESS_HR_V  \
# 0  5873599   8641867         9  20180509             82.0         1,890
# 1  5873599   6616320        21  20180611            105.0         1,604
# 2  5873599   5886172        40  20180624             41.0           632
# 3  5873884   1050889        15  20180913            160.0         1,035
# 4  5874461  10298270         5  20180412             13.0           298
#
#   DVC_CTG_NM       ZON_NM  CITY_NM
# 0     mobile      Daejeon  Daejeon
# 1     mobile        Busan    Busan
# 2     mobile      Daejeon  Daejeon
# 3     mobile  Gyeonggi-do   Anyang
# 4     mobile        Seoul    Seoul

# %%
sess.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2712907 entries, 0 to 2712906
# Data columns (total 9 columns):
# CLNT_ID            int64
# SESS_ID            int64
# SESS_SEQ           int64
# SESS_DT            int64
# TOT_PAG_VIEW_CT    float64
# TOT_SESS_HR_V      object
# DVC_CTG_NM         object
# ZON_NM             object
# CITY_NM            object
# dtypes: float64(1), int64(4), object(4)
# memory usage: 186.3+ MB

# %%
prod = pd.read_csv('gdrive/My Drive/공모전/엘포인트/Pruduct.csv')
prod.head()
# Out:
# /usr/local/lib/python3.6/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#    CLNT_ID   SESS_ID  HITS_SEQ    PD_C                         PD_ADD_NM  \
# 0  4139680   7605037        12  642112                           색상:워터멜론
# 1  4140076  10189797        13  570603  색상:BLK0_(BLK0)BLACK|사이즈:120 / 2개
# 2  4142395   6158159        85  179538                         (not set)
# 3  4144914   7935714        12  554336      색상:블랙|사이즈:160cm(12~13세) / 1개
# 4  4144917   6406509        78  190306                                5개
#
#   PD_BRA_NM PD_BUY_AM PD_BUY_CT
# 0   [바비브라운]    39,000         1
# 1       데상트    39,000         2
# 2     [아베다]    39,000         1
# 3   아디다스 키즈    39,000         1
# 4      데코르테    39,000         5

# %%
prod.tail()
# Out:
#          CLNT_ID   SESS_ID  HITS_SEQ    PD_C  \
# 5024901  4132078  10042817        76  527736
# 5024902  4133768   7272433        31  284643
# 5024903  4133768   7946785        38  284643
# 5024904  4134952   5355187       113  840639
# 5024905  4136808   8930953        33  442584
#
#                                  PD_ADD_NM    PD_BRA_NM PD_BUY_AM PD_BUY_CT
# 5024901  코드:s_kk_1205030|사이즈:BLACK 90 / 1개     아디다스(의류)    39,000         1
# 5024902              색상:(42)블루|사이즈:55 / 1개     제이제이 지고트    39,000         1
# 5024903            색상:(60)아이보리|사이즈:55 / 1개     제이제이 지고트    39,000         1
# 5024904                    사이즈:Medium / 1개           배럴    39,000         1
# 5024905                      색상:1.블랙/사이즈:M  [언더아머(스포츠)]    39,000         1

# %%
prod.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5024906 entries, 0 to 5024905
# Data columns (total 8 columns):
# CLNT_ID      int64
# SESS_ID      int64
# HITS_SEQ     int64
# PD_C         int64
# PD_ADD_NM    object
# PD_BRA_NM    object
# PD_BUY_AM    object
# PD_BUY_CT    object
# dtypes: int64(4), object(4)
# memory usage: 306.7+ MB

# %%
prod['PD_BUY_CT'] = prod['PD_BUY_CT'].str.replace(',','')
pd.to_numeric(prod['PD_BUY_CT'])
# Out:
# 0          1.0
# 1          2.0
# 2          1.0
# 3          1.0
# 4          5.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0
# 10         1.0
# 11         1.0
# 12         1.0
# 13         1.0
# 14         1.0
# 15         1.0
# 16         1.0
# 17         1.0
# 18         2.0
# 19         1.0
# 20         1.0
# 21         1.0
# 22         1.0
# 23         1.0
# 24         2.0
# 25         1.0
# 26         1.0
# 27         1.0
# 28         1.0
# 29         1.0
#           ...
# 5024876    NaN
# 5024877    NaN
# 5024878    NaN
# 5024879    NaN
# 5024880    NaN
# 5024881    NaN
# 5024882    NaN
# 5024883    NaN
# 5024884    NaN
# 5024885    NaN
# 5024886    NaN
# 5024887    NaN
# 5024888    NaN
# 5024889    NaN
# 5024890    NaN
# 5024891    NaN
# 5024892    NaN
# 5024893    NaN
# 5024894    NaN
# 5024895    NaN
# 5024896    NaN
# 5024897    NaN
# 5024898    NaN
# 5024899    NaN
# 5024900    NaN
# 5024901    NaN
# 5024902    NaN
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-69c2598896a1> in <module>()
# ----> 1 pd_buy_ct = [int(i) for i in pd_buy_ct]
#
# <ipython-input-37-69c2598896a1> in <listcomp>(.0)
# ----> 1 pd_buy_ct = [int(i) for i in pd_buy_ct]
#
# ValueError: invalid literal for int() with base 10: '1,440'

# %%
# Out:
# 1
